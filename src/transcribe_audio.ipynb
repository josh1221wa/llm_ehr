# %%
from dotenv import load_dotenv
import os

load_dotenv("../tokens.env")
# Out:
# True

# %%
from transformers import pipeline

asr_pipeline = pipeline(
    "automatic-speech-recognition",
    model="openai/whisper-base",
)
# Out:
# Device set to use cuda:0

# %%
text = asr_pipeline("../sample_audio.wav", return_timestamps=True)
# Out:
# d:\anaconda3\envs\llm_ehr_env\lib\site-packages\transformers\models\whisper\generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
text
# Out:
# {'text': " Hello. Hello. Hi. Hi. Um, should we stop? Yeah. Okay. Hello. Um, the boys are how can I help you this morning? I, um, I've just had some, um, diary for the last three days. Um, and it's been affecting me. I need to stay close to the toilet and, um, yeah, it's been affecting my day to day activities. Yeah. I'm sorry to hear that. Um, and when you say diary, what What do you mean by diary? Do you mean you're going to a toilet more often or are your stools more loose? Yeah, so it's like loose and watery stool going to the toilet quite often and like some pain in my like lower stomach. Okay. And how many times a day are you going? Let's say I've lost a couple of days. Probably like six, seven times a day. Six, seven times a day. And you may have mentioned the main watery. Have you noticed any other things like blood in your stools? No, no blood, yeah just watery and loose still. Okay, and you mentioned you've had some pain in your tummy as well. Yep. Whereabouts is a pain? It's actually in my lower abdomen, so like, yeah just to one side. One side? What side is that? On the left side. Yeah, so I like it. Then can you describe the pain to me? Yeah, it feels like a cramp, like a muscular cramp. crap and yeah I feel a bit weak in shaky. And is it pain, is it there all the time or does it come and go? It comes and goes. Does it pain move anywhere else? For example, twer is your back? No, just mainly my stomach. Okay, fine. And you mentioned you've been feeling quite weak in shaky as well. Would you be more shaky? Do you mean you've been feeling feverish for example? Yeah, it doesn't feel like, yeah, I just made it for a week. I haven't had a fever at the moment, but I did notice a temperature when the symptoms started. So, yeah, around about three or four days ago. You measured your temperature then? Yeah, I didn't measure my temperature, no, but I felt just a bit hot. Okay, okay. Any other symptoms like sweating or... No. And any vomiting at all? Yes, so I vomited at the start of the symptoms, but now I've stopped vomiting. You stopped vomiting, okay? And was your vomiting? I know it's not nice we've talked about, but was it just normal food colour? Yeah, just normal vomit. And there was no blood in your vomit. Is that right? No, no. And any other symptoms at all? So you mentioned tummy pain, you mentioned diarrhea, you mentioned vomiting. anything else that comes to mind? I had a loss of appetite. I haven't been eating as much, but I've been able to hold down fluids. Okay, so you're drinking fluids. What kind of foods have you managed to eat, please? Just soups and, yeah, light foods, like smoothies and, yeah, liquid foods mainly. Okay, fine. And so, they started just three days ago to symptoms. Are you aware of any triggers which may have caused the symptoms to kick on? So for example, things like takeaway foods or eating out or being around other people who would sing the symptoms? Yeah, so I had takeaway about four days ago, but other than that, I've been eating normally I think unusual, yeah. Do you remember where you ate? Yeah, I ate a Chinese restaurant with friends. Okay. Anyone else on well with similar symptoms? So no one else in the family, so I've wiped in two kids and one child was vomiting, but they haven't got diarrhea. There's no one with the same symptoms. Okay, okay. Fine. Right. And in terms of your overall health, Are you normally fissing well? Yeah, I mean, other than asthma, I'm using inhaler, everything else is fine. Okay. And did you ask them a well controlled? Yeah, that's fine. I just, yeah, use an inhaler and that's under control. And you don't have any other tummy problem, bowel problem, that should be aware of? No. No, okay. And pardon the inhalers, do you take any other medications? No, no other medications. Okay, fine. In terms of just all your data to their life, you said it's been affecting your life. Yeah. In what way has it been affecting your life? So I need to stay close to the toilet b ...
#  'chunks': [{'timestamp': (0.0, 11.2),
#    'text': ' Hello. Hello. Hi. Hi. Um, should we stop? Yeah. Okay. Hello. Um, the boys are how can I help'},
#   {'timestamp': (11.2, 19.24),
#    'text': " you this morning? I, um, I've just had some, um, diary for the last three days. Um, and"},
#   {'timestamp': (19.24, 24.16),
#    'text': " it's been affecting me. I need to stay close to the toilet and, um, yeah, it's been affecting"},
#   {'timestamp': (24.16, 29.48),
#    'text': " my day to day activities. Yeah. I'm sorry to hear that. Um, and when you say diary, what"},
#   {'timestamp': (29.48, 0.0), 'text': ''},
#   {'timestamp': (3.44, 4.68),
#    'text': " What do you mean by diary? Do you mean you're going to a toilet more often or are your stools more loose?"},
#   {'timestamp': (4.68, 11.64),
#    'text': " Yeah, so it's like loose and watery stool going to the toilet quite often and like some"},
#   {'timestamp': (11.64, 14.48), 'text': ' pain in my like lower stomach.'},
#   {'timestamp': (14.48, 18.56),
#    'text': " Okay. And how many times a day are you going? Let's say I've lost a couple of days."},
#   {'timestamp': (18.56, 21.12),
#    'text': ' Probably like six, seven times a day.'},
#   {'timestamp': (21.12, 22.44), 'text': ' Six, seven times a day.'},
#   {'timestamp': (22.44, 25.92),
#    'text': ' And you may have mentioned the main watery. Have you noticed any other things like blood'},
#   {'timestamp': (25.92, 26.92), 'text': ' in your stools?'},
#   {'timestamp': (26.92, 0.0), 'text': ''},
#   {'timestamp': (3.0, 6.0),
#    'text': " No, no blood, yeah just watery and loose still. Okay, and you mentioned you've had some pain in your tummy as well."},
#   {'timestamp': (6.0, 7.0), 'text': ' Yep.'},
#   {'timestamp': (7.0, 8.0), 'text': ' Whereabouts is a pain?'},
#   {'timestamp': (8.0, 14.0),
#    'text': " It's actually in my lower abdomen, so like, yeah just to one side."},
#   {'timestamp': (14.0, 15.0), 'text': ' One side?'},
#   {'timestamp': (15.0, 17.0), 'text': ' What side is that?'},
#   {'timestamp': (17.0, 18.0), 'text': ' On the left side.'},
#   {'timestamp': (18.0, 19.0), 'text': ' Yeah, so I like it.'},
#   {'timestamp': (19.0, 21.0),
#    'text': ' Then can you describe the pain to me?'},
#   {'timestamp': (21.0, 26.0),
#    'text': ' Yeah, it feels like a cramp, like a muscular cramp.'},
#   {'timestamp': (26.0, 0.0), 'text': ''},
#   {'timestamp': (7.68, 12.88),
#    'text': ' crap and yeah I feel a bit weak in shaky. And is it pain, is it there all the time or does it come and go? It comes and goes. Does it pain move anywhere else? For example, twer is your back?'},
#   {'timestamp': (14.24, 19.44),
#    'text': " No, just mainly my stomach. Okay, fine. And you mentioned you've been feeling quite weak in"},
#   {'timestamp': (19.44, 24.16),
#    'text': " shaky as well. Would you be more shaky? Do you mean you've been feeling feverish for example?"},
#   {'timestamp': (25.44, 0.0), 'text': ''},
#   {'timestamp': (5.92, 12.84),
#    'text': " Yeah, it doesn't feel like, yeah, I just made it for a week. I haven't had a fever at the moment, but I did notice a temperature when the symptoms started. So, yeah, around"},
#   {'timestamp': (12.84, 16.56),
#    'text': ' about three or four days ago. You measured your temperature then?'},
#   {'timestamp': (16.56, 20.84),
#    'text': " Yeah, I didn't measure my temperature, no, but I felt just a bit hot."},
#   {'timestamp': (20.84, 25.04),
#    'text': ' Okay, okay. Any other symptoms like sweating or...'},
#   {'timestamp': (25.04, 27.04), 'text': ' No.'},
#   {'timestamp': (27.04, 0.0), 'text': ''},
#   {'timestamp': (2.0, 9.0),
#    'text': " And any vomiting at all? Yes, so I vomited at the start of the symptoms, but now I've stopped vomiting."},
#   {'timestamp': (9.0, 16.0),
#    'text': " You stopped vomiting, okay? And was your vomiting? I know it's not nice we've talked about, but was it just normal food colour?"},
#   {'timestamp': (16.0, 18.0), 'text': ' Yeah, just normal vomit.'},
#   {'timestamp': (18.0, 20.0),
#    'text': ' And there was no blood in your vomit. Is that right?'},
#   {'timestamp': (20.0, 22.0), 'text': ' No, no.'},
#   {'timestamp': (22.0, 28.0),
#    'text': ' And any other symptoms at all? So you mentioned tummy pain, you mentioned diarrhea, you mentioned vomiting.'},
#   {'timestamp': (28.0, 0.0), 'text': ''},
#   {'timestamp': (3.0, 6.0),
#    'text': ' anything else that comes to mind? I had a loss of appetite.'},
#   {'timestamp': (6.0, 11.0),
#    'text': " I haven't been eating as much, but I've been able to hold down fluids."},
#   {'timestamp': (11.0, 14.0), 'text': " Okay, so you're drinking fluids."},
#   {'timestamp': (14.0, 17.0),
#    'text': ' What kind of foods have you managed to eat, please?'},
#   {'timestamp': (17.0, 25.0),
#    'text': ' Just soups and, yeah, light foods, like smoothies and, yeah, liquid foods mainly.'},
#   {'timestamp': (25.0, 0.0), 'text': ''},
#   {'timestamp': (6.44, 11.32),
#    'text': ' Okay, fine. And so, they started just three days ago to symptoms. Are you aware of any triggers which may have caused the symptoms to kick on? So for example, things like takeaway'},
#   {'timestamp': (11.32, 15.32),
#    'text': ' foods or eating out or being around other people who would sing the symptoms?'},
#   {'timestamp': (15.32, 25.2),
#    'text': " Yeah, so I had takeaway about four days ago, but other than that, I've been eating normally"},
#   {'timestamp': (25.2, 0.0), 'text': ''},
#   {'timestamp': (2.12, 4.44),
#    'text': ' I think unusual, yeah. Do you remember where you ate?'},
#   {'timestamp': (4.44, 7.88),
#    'text': ' Yeah, I ate a Chinese restaurant with friends.'},
#   {'timestamp': (7.88, 8.64), 'text': ' Okay.'},
#   {'timestamp': (8.64, 12.08),
#    'text': ' Anyone else on well with similar symptoms?'},
#   {'timestamp': (12.08, 13.56), 'text': ' So no one else in the family,'},
#   {'timestamp': (13.56, 18.08),
#    'text': " so I've wiped in two kids and one child was vomiting,"},
#   {'timestamp': (18.08, 19.96), 'text': " but they haven't got diarrhea."},
#   {'timestamp': (19.96, 22.24),
#    'text': " There's no one with the same symptoms."},
#   {'timestamp': (22.24, 23.48), 'text': ' Okay, okay.'},
#   {'timestamp': (23.48, 24.32), 'text': ' Fine.'},
#   {'timestamp': (25.56, 26.4), 'text': ' Right.'},
#   {'timestamp': (26.4, 29.24),
#    'text': ' And in terms of your overall health,'},
#   {'timestamp': (29.24, 0.0), 'text': ''},
#   {'timestamp': (2.0, 9.0),
#    'text': " Are you normally fissing well? Yeah, I mean, other than asthma, I'm using inhaler, everything else is fine."},
#   {'timestamp': (9.0, 10.0), 'text': ' Okay.'},
#   {'timestamp': (10.0, 12.0),
#    'text': ' And did you ask them a well controlled?'},
#   {'timestamp': (12.0, 14.0), 'text': " Yeah, that's fine."},
#   {'timestamp': (14.0, 18.0),
#    'text': " I just, yeah, use an inhaler and that's under control."},
#   {'timestamp': (18.0, 22.0),
#    'text': " And you don't have any other tummy problem, bowel problem, that should be aware of?"},
#   {'timestamp': (22.0, 23.0), 'text': ' No.'},
#   {'timestamp': (23.0, 24.0), 'text': ' No, okay.'},
#   {'timestamp': (24.0, 28.0),
#    'text': ' And pardon the inhalers, do you take any other medications?'},
#   {'timestamp': (28.0, 0.0), 'text': ''},
#   {'timestamp': (2.4, 3.4), 'text': ' No, no other medications. Okay, fine.'},
#   {'timestamp': (3.4, 5.16),
#    'text': ' In terms of just all your data to their life,'},
#   {'timestamp': (5.16, 7.04),
#    'text': " you said it's been affecting your life."},
#   {'timestamp': (7.04, 7.88), 'text': ' Yeah.'},
#   {'timestamp': (7.88, 10.04),
#    'text': ' In what way has it been affecting your life?'},
#   {'timestamp': (10.04, 12.56),
#    'text': ' So I need to stay close to the toilet'},
#   {'timestamp': (12.56, 16.28),
#    'text': ' because I go quite frequently during these past three days.'},
#   {'timestamp': (16.28, 17.28), 'text': ' Okay.'},
#   {'timestamp': (17.28, 21.28),
#    'text': " Yeah, other than that, it's the main concern."},
#   {'timestamp': (21.28, 23.68),
#    'text': ' And are you currently working at the moment?'},
#   {'timestamp': (23.68, 24.76), 'text': ' I work.'},
#   {'timestamp': (24.76, 26.08), 'text': ' Yeah, I work.'},
#   {'timestamp': (26.08, 27.76), 'text': ' Working at work.'},
#   {'timestamp': (27.76, 29.28), 'text': " I'm in the countenance."},
#   {'timestamp': (29.28, 0.0), 'text': ''},
#   {'timestamp': (2.0, 3.0),
#    'text': ' Okay, have you been going to work last three days? Are you going to home?'},
#   {'timestamp': (3.0, 5.0), 'text': " Yeah, I've been going to work."},
#   {'timestamp': (5.0, 6.0), 'text': ' Okay.'},
#   {'timestamp': (6.0, 7.0), 'text': ' I must be difficult for you then.'},
#   {'timestamp': (7.0, 9.0), 'text': " Yeah, it's been quite difficult."},
#   {'timestamp': (9.0, 10.0), 'text': ' Right.'},
#   {'timestamp': (10.0, 13.0),
#    'text': ' And you said you mentioned you live with a wife and two children, is that right?'},
#   {'timestamp': (13.0, 14.0), 'text': ' Yes, yeah.'},
#   {'timestamp': (14.0, 15.0), 'text': ' All right.'},
#   {'timestamp': (15.0, 17.0),
#    'text': ' Just a couple of other questions we need to ask.'},
#   {'timestamp': (17.0, 18.0), 'text': ' Do you smoke at all?'},
#   {'timestamp': (18.0, 20.0), 'text': " No, I don't smoke."},
#   {'timestamp': (20.0, 22.0),
#    'text': ' Do you drink much in a way of alcohol?'},
#   {'timestamp': (22.0, 24.0), 'text': " No, I don't drink alcohol though."},
#   {'timestamp': (24.0, 25.0), 'text': ' Okay.'},
#   {'timestamp': (25.0, 29.0),
#    'text': ' So, normally at this stage, I like to...'},
#   {'timestamp': (29.0, 0.0), 'text': ''},
#   {'timestamp': (8.48, 11.84),
#    'text': " examine you, but haven't listened to your stories. Just recap, for the last three days, you've been having a loose stool diarrhea, a bit of tummy pain, mainly on the left hand"},
#   {'timestamp': (11.84, 17.18),
#    'text': " side, vomiting and feeling quite weak and ethargic. You mentioned you haven't just"},
#   {'timestamp': (17.18, 20.36),
#    'text': ' tried to take away as well, three days ago, and I wonder whether that might be the cause'},
#   {'timestamp': (20.36, 27.32),
#    'text': ' of your problems. It seems like you may have something called gastroenteritis, which'},
#   {'timestamp': (27.32, 0.0), 'text': ''},
#   {'timestamp': (7.88, 17.3),
#    'text': " essentially the tummy bug or infection of your tummy mainly caused by viruses but it can be a possibility of bacteria causing symptoms. At this stage what we'd recommend is just"},
#   {'timestamp': (17.3, 21.84),
#    'text': " what we say conservative management so I don't think you need any antibersics is really"},
#   {'timestamp': (21.84, 29.04),
#    'text': ' just making sure your world hydrated for drinking fluids.'},
#   {'timestamp': (29.04, 0.0), 'text': ''},
#   {'timestamp': (5.68, 9.24),
#    'text': ' There are things like dire light you can get from the pharmacy, which it helps replenish some of your minerals and vitamins.'},
#   {'timestamp': (9.24, 14.84),
#    'text': ' If you are having vomiting and diarrhea, I would recommend that in the first couple of days.'},
#   {'timestamp': (14.84, 20.16),
#    'text': ' If you are feeling feverish and weak, taking some paracetamol, a few tablets up to four'},
#   {'timestamp': (20.16, 22.56),
#    'text': ' times a day for the first few days can also help.'},
#   {'timestamp': (22.56, 25.0),
#    'text': ' I was certainly going to advise you to take some time to work, actually.'},
#   {'timestamp': (25.0, 26.88), 'text': " I know you're quite keen to work."},
#   {'timestamp': (26.88, 0.0), 'text': ''},
#   {'timestamp': (2.16, 3.84), 'text': ' I would say next two to three days,'},
#   {'timestamp': (5.44, 7.12),
#    'text': ' a chinklier from your system, takes some time off and rest.'},
#   {'timestamp': (9.12, 12.32),
#    'text': " If your symptoms haven't got better in three to four days,"},
#   {'timestamp': (12.32, 14.32),
#    'text': " I'll write it down back in senior again."},
#   {'timestamp': (14.32, 15.16), 'text': ' Okay, sure.'},
#   {'timestamp': (15.16, 16.0), 'text': ' Because if it is ongoing,'},
#   {'timestamp': (16.0, 17.6),
#    'text': ' then we have to wonder whether something else'},
#   {'timestamp': (17.6, 18.92), 'text': ' could be symptoms.'},
#   {'timestamp': (18.92, 19.76), 'text': ' Yeah.'},
#   {'timestamp': (19.76, 21.28),
#    'text': ' And we may need to do further tinnus,'},
#   {'timestamp': (21.28, 23.64),
#    'text': ' like taking a sample of your stool,'},
#   {'timestamp': (23.64, 27.48),
#    'text': ' so we can test that, et cetera, et cetera.'},
#   {'timestamp': (27.48, 28.72), 'text': ' Yeah, sure, yeah.'},
#   {'timestamp': (28.72, 29.56), 'text': " How's that sound?"},
#   {'timestamp': (0.0, 1.44), 'text': ' That sounds great, yeah.'},
#   {'timestamp': (1.44, 3.28), 'text': ' Do you have any questions for me?'},
#   {'timestamp': (3.28, 5.72), 'text': ' No, no further questions.'},
#   {'timestamp': (5.72, 6.72), 'text': ' Okay.'},
#   {'timestamp': (6.72, 8.92), 'text': ' Is the treatment plan clear?'},
#   {'timestamp': (8.92, 11.08), 'text': " Yeah, yeah, that's very clear."},
#   {'timestamp': (11.08, 12.08), 'text': ' Thank you.'},
#   {'timestamp': (12.08, 13.08), 'text': ' Great.'},
#   {'timestamp': (13.08, 14.08), 'text': ' I wish you all the best.'},
#   {'timestamp': (14.08, 15.08), 'text': ' Okay.'},
#   {'timestamp': (15.08, 16.08), 'text': ' Thank you.'},
#   {'timestamp': (16.08, 17.08), 'text': ' Bye.'}]}
